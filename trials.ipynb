# %%
print("hello")
# Out:
# hello

# %%
# %pip install langchain
# Out:
# ...
#   Using cached langchain-0.3.15-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached langchain_core-0.3.31-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached langchain_text_splitters-0.3.5-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached langsmith-0.3.1-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl.metadata (61 kB)
# ...
#   Using cached pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached attrs-24.3.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached orjson-3.10.15-cp39-cp39-win_amd64.whl.metadata (42 kB)
# ...
#   Using cached zstandard-0.23.0-cp39-cp39-win_amd64.whl.metadata (3.0 kB)
# ...
#   Using cached pydantic_core-2.27.2-cp39-cp39-win_amd64.whl.metadata (6.7 kB)
# ...

# %%
# %pip install langchain
# %pip install pinecone-client
# %pip install huggingface_hub
# %pip install pymupdf
# %pip install ctransformers
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached pinecone_client-5.0.1-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached pinecone_plugin_inference-1.1.0-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# ...
# Using cached pinecone_client-5.0.1-py3-none-any.whl (244 kB)
# Using cached pinecone_plugin_inference-1.1.0-py3-none-any.whl (85 kB)
# Using cached pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\21697\anaconda3\envs\mental_chatbot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#   Using cached huggingface_hub-0.27.1-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached huggingface_hub-0.27.1-py3-none-any.whl (450 kB)
# ...

# %%
# %pip install langchain huggingface_hub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U langchain-community
# Out:
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ------------ --------------------------- 0.8/2.5 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 6.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script dotenv.exe is installed in 'c:\Users\21697\anaconda3\envs\mental_chatbot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from langchain import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Pinecone
import pinecone
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain.llms import CTransformers

# %%
#database
PINECONE_API_KEY="pcsk_7LvmwC_SjHodQesMuSEJmRmLuwEKyhkjLzdnhUnii9CnRSndBtUHVuUafr4j6zKKYkw2fV"
PINECONE_API_ENV="us-east-1"

# %%
#extract data from pdf 
def load_pdf(data):
    loader = DirectoryLoader(data,glob="start.pdf",Loader_clr=PyPDFLoader)
    documents = loader.load()
    return documents

# %%
# %pip install pypdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.document_loaders import PyPDFLoader

def load_pdf(data):
    # Initialize PyPDFLoader with the file path
    loader = PyPDFLoader(data)  # Use the actual file path or directory here
    documents = loader.load()
    return documents

# %%
pdf_path = "./data/DSM-5-TR.pdf"
documents = load_pdf(pdf_path)
print(documents)
# Out:
# [Document(metadata={'source': './data/DSM-5-TR.pdf', 'page': 0, 'page_label': '1'}, page_content=' \n \n \n \n \nDSM-5-TR® Update \nSupplement to \nDiagnostic and Statistical Manual of  \nMental Disorders, Fifth Edition,  \nText Revision \n \n \n \n \n \nSeptember 2024 \n \nPrevious updates:  \nSeptember 2023 \nSeptember 2022 \n \n \n'), Document(metadata={'source': './data/DSM-5-TR.pdf', 'page': 1, 'page_label': '2'}, page_content=' \n \nCopyright © 2024 American Psychiatric Association.  \nDSM, DSM-5, and DSM-5-TR are registered trademarks of the American Psychiatric Association. \nUse of these terms is prohibited without permission of the American Psychiatric Association. \nALL RIGHTS RESERVED. Unless authorized in writing by the APA (APA), no part of this supplement \nmay be reproduced or used in a manner inconsistent with the APA’s copyright. This prohibition \napplies to unauthorized uses or reproductions in any form, including electronic applications. \nCorrespondence regardin
# ...
